# %%
import pandas as pd
import numpy as np

# %%
path='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
#  Analyzing individual feature patterns using visualization

# install seaborn

# %%
# %%capture
! pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#  list the data types for each column

print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
#  can calculate the correlation between variable types int64 and float64

df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
#  Find the correlation between the columns

#  bore
#  stroke
#  compression-ratio
#  horsepower

# %%
df[["bore", "stroke", "compression-ratio", "horsepower"]].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
#  Continuous numerical variables

#  variables that may contain any value within some range.   int or float

#  scatter plot, linear relationship using regplot

# %%
#  scatter plot of engine-size and price 

sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 56075.92026559302)

# %%
# correlation between engine-size and price

df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
#  scatter plot of highway-mpg and price

sns.regplot(x="highway-mpg", y="price", data=df)

# %%
df[["highway-mpg", "price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
# scatter plot of peak-rpm and price

sns.regplot(x="peak-rpm", y="price", data=df)

# %%
df[["peak-rpm", "price"]].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
#  scatter plot of stroke and price

sns.regplot(x="stroke", y="price", data=df)

# %%
df[["stroke", "price"]].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %%
#  categorical variables

#  describe a characteristic of a data unit and are selected from a small group of categories
#  object or int64 type   

#  boxplots

# %%
#  relationship between body-style and price

#  boxplot
sns.boxplot(x="body-style", y="price", data=df)

# %%
#  relationship between engine-location and price

sns.boxplot(x="engine-location", y="price", data=df)

# %%
#  relationship between drive-wheels and price

sns.boxplot(x="drive-wheels", y="price", data=df)

# %%
#  Descriptive Statistical Analysis 

#  dataframe.describe()

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
# .describe() omits NaNs, Object types

#  .describe() on object types

df.describe(include=["object"])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
#  Value Counts

#  how many units of each characteristic/variable we have 

#  .value_counts()

#  only works on Pandas series, not Pandas Dataframes:   include only 1 bracket opposed to 2

#  df["drive-wheels"] and not df[["drive-wheels"]]

# %%
df["drive-wheels"].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
#  convert the series to a dataframe 

df["drive-wheels"].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
drive_wheels_counts = df["drive-wheels"].value_counts().to_frame()
drive_wheels_counts.head()
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
drive_wheels_counts.rename(columns={"drive-wheels": "value_counts"}, inplace=True)
drive_wheels_counts.head()
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %%
#  rename the index to drive-wheels

drive_wheels_counts.index.name = "drive-wheels"
drive_wheels_counts.head()
# Out:
#               value_counts
# drive-wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %%
#  for variable engine-location

# %%
engine_loc_counts = df["engine-location"].value_counts().to_frame()
engine_loc_counts
# Out:
#        engine-location
# front              198
# rear                 3

# %%
engine_loc_counts.rename(columns={"engine-location": "value_counts"}, inplace=True)
engine_loc_counts
# Out:
#        value_counts
# front           198
# rear              3

# %%
engine_loc_counts.index.name="engine-location"
engine_loc_counts
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %%
engine_loc_counts.head(10)
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %%
#  engine location would not be a good predictor of price
#  since we only have 3 cars with rear engine thus the results are skewed.

# %%
#  basics of Grouping

#  group data by different categories
#  so analysis can be performed on the individual groups

# %%
#  see the different categories

df["drive-wheels"].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
#  want to know on average, which type of drive-wheels is most valuable
#  we can group drive-wheels and average them

df_group_one = df[["drive-wheels", "body-style", "price"]]
df_group_one
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]

# %%
#  calculate the average price for each of the different categories of data

df_group_one = df_group_one.groupby(["drive-wheels"], as_index=False).mean()
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
#  group by multiple variables

df_gp_test = df[["drive-wheels", "body-style", "price"]]
df_gp_test
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]

# %%
grouped_test1 = df_gp_test.groupby(["drive-wheels", "body-style"], as_index=False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
#  create pivot table

grouped_pivot = grouped_test1.pivot(index="drive-wheels", columns="body-style")
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
#  fill missing values wtih 0

grouped_pivot = grouped_pivot.fillna(0)
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
#  find the average price of each car based on body-style

df_gp_test2 = df[["body-style", "price"]]
df_gp_test2
# Out:
#       body-style    price
# 0    convertible  13495.0
# 1    convertible  16500.0
# 2      hatchback  16500.0
# 3          sedan  13950.0
# 4          sedan  17450.0
# ..           ...      ...
# 196        sedan  16845.0
# 197        sedan  19045.0
# 198        sedan  21485.0
# 199        sedan  22470.0
# 200        sedan  22625.0
#
# [201 rows x 2 columns]

# %%
grouped_test_bodystyle = df_gp_test2.groupby(["body-style"], as_index=False).mean()
grouped_test_bodystyle
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
#  heat map

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.pcolor(grouped_pivot, cmap="RdBu")
plt.colorbar()
plt.show()

# %%
#  heatmap plots the price proportional to color with repect to drive-wheels and body-style

#  visualize how the price is related to drive wheel and body style

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap="RdBu")

#  label names
row_label = grouped_pivot.columns.levels[1]
col_label = grouped_pivot.index

#  move ticks and labels to center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#  insert labels
ax.set_xticklabels(row_label, minor=False)
ax.set_yticklabels(col_label, minor=False)

#  rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
#  Correlation and Causation

#  correlation: measure of the extend of interdependence between variables
#  causation: relationship between causes and effect between two variables


#  Pearson Correlation
#  measures linear dependence between 2 variables X and Y

#  resulting coefficient is a value between -1 and 1 inclusive
#  1: total positive linear correlation
#  0: no linear correlation - two variables don't affect each other
# -1: total negative linear correlation 

# pearson correlation = df.corr()

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
#  want to know the significance of the correlation estimate 

#  p-value:
#  probability that the correlation between these 2 variables is statistically significant 

#  significance level of 0.05 = 95% confident that the correlation between the variables is significant 


#  < 0.001    strong evidence correlation is significant 
#  < 0.05     moderate 
#  < 0.1      weak 
#  > 0.1      no evidence that the correlation is significant

# %%
from scipy import stats

# %%
#  pearson correlation coefficient and p-value of 


#  wheel-base vs price

pearson_coef, p_val = stats.pearsonr(df["wheel-base"], df["price"])

print("Pearson Correlation Coefficient is ", pearson_coef, " with P-Value of ", p_val)
# Out:
# Pearson Correlation Coefficient is  0.584641822265508  with P-Value of  8.076488270733218e-20

# %%
# p_val < 0.001, correlation between wheel-base and price is statistically significant
#  although the linear relationship isn't extrememly strong

# %%
#  horsepower vs price

pearson_coef, p_val = stats.pearsonr(df["horsepower"], df["price"])

print("Pearson Correlation Coefficient is ", pearson_coef, " with P-Value of ", p_val)
# Out:
# Pearson Correlation Coefficient is  0.809574567003656  with P-Value of  6.369057428259557e-48

# %%
#  p_val < 0.001, is statistically significant
#  and linear relationship is quite string

# %%
#  length vs price

pearson_coef, p_val = stats.pearsonr(df["length"], df["price"])

print("Pearson Correlation Coefficient is ", pearson_coef, " with P-Value of ", p_val)
# Out:
# Pearson Correlation Coefficient is  0.690628380448364  with P-Value of  8.016477466158986e-30

# %%
#  < 0.001, is statistically significant
#  and linear relation is moderately strong

# %%
#  width vs price

pearson_coef, p_val = stats.pearsonr(df["width"], df["price"])

print("Pearson Correlation Coefficient is ", pearson_coef, " with P-Value of ", p_val)
# Out:
# Pearson Correlation Coefficient is  0.7512653440522674  with P-Value of  9.200335510481516e-38

# %%
#  < 0.001, is statistically significant 
#  linear relationship is quite strong

# %%
#  curb-weight vs price

pearson_coef, p_val = stats.pearsonr(df["curb-weight"], df["price"])

print("Pearson Correlation Coefficient is ", pearson_coef, " with P-Value of ", p_val)
# Out:
# Pearson Correlation Coefficient is  0.8344145257702846  with P-Value of  2.1895772388936914e-53

# %%
#  < 0.001, is statistically significant 
#  linear relationship is quite strong

# %%
#  engine-size vs price

pearson_coef, p_val = stats.pearsonr(df["engine-size"], df["price"])

print("Pearson Correlation Coefficient is ", pearson_coef, " with P-Value of ", p_val)
# Out:
# Pearson Correlation Coefficient is  0.8723351674455185  with P-Value of  9.265491622198389e-64

# %%
#  < 0.001, is statistically significant 
#  linear relationship is very strong

# %%
#  bore vs price

pearson_coef, p_val = stats.pearsonr(df["bore"], df["price"])

print("Pearson Correlation Coefficient is ", pearson_coef, " with P-Value of ", p_val)
# Out:
# Pearson Correlation Coefficient is  0.5431553832626601  with P-Value of  8.049189483935489e-17

# %%
#  < 0.001, is statistically significant 
#  the linear relationship is only moderate

# %%
#  city-mpg vs price

pearson_coef, p_val = stats.pearsonr(df["city-mpg"], df["price"])

print("Pearson Correlation Coefficient is ", pearson_coef, " with P-Value of ", p_val)
# Out:
# Pearson Correlation Coefficient is  -0.6865710067844677  with P-Value of  2.321132065567674e-29

# %%
#  < 0.001, is statistically significant 
#  relationship is negative and moderately strong

# %%
#  highway-mpg vs price

pearson_coef, p_val = stats.pearsonr(df["highway-mpg"], df["price"])

print("Pearson Correlation Coefficient is ", pearson_coef, " with P-Value of ", p_val)
# Out:
# Pearson Correlation Coefficient is  -0.7046922650589529  with P-Value of  1.7495471144477352e-31

# %%
#  < 0.001, is statistically significant
#  relationship is negative and moderately strong

# %%
#  ANOVA   analysis of variance

#  test whether there are significant differences between the means of 2 or more groups


#  returns F-test score and p-value

#  F-test score: larger score means there is a larger difference between the means. assumption is theyre the same
#  p-value: how statistically significant is our calculated score value. 



#  if price is strongly correlated, expect sizeable F test score and small p-value


#  ANOVA analyzes the difference between different groups of the same variable

#  groupby function

# f_oneway to obtain f-test and pvalue

# %%
#  see if different types "drive-wheels" impact price

grouped_test2 = df_gp_test[["drive-wheels", "price"]].groupby(["drive-wheels"])
grouped_test2.head()
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 2            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# 5            fwd  15250.0
# 6            fwd  17710.0
# 7            fwd  18920.0
# 8            fwd  23875.0
# 9            rwd  16430.0
# 10           rwd  16925.0
# 136          4wd   7603.0
# 140          4wd   9233.0
# 141          4wd  11259.0
# 144          4wd   8013.0

# %%
df_gp_test
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]

# %%
#  obtain the values of the method group 

grouped_test2.get_group("4wd")["price"]
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %%
#  ANOVA

f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'], grouped_test2.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %%
#  F-test = strong correlation
#  p-value = imply almost certain statistical significance

# %%
#  separately fwd and rwd

f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 130.5533160959111 , P = 2.2355306355677845e-23

# %%
#  4wd and rwd

f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'], grouped_test2.get_group('rwd')['price'])  
   
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 8.580681368924756 , P = 0.004411492211225333

# %%
#  4wd and fwd

f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'], grouped_test2.get_group('fwd')['price'])  
 
print("ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 0.665465750252303 , P = 0.41620116697845666
